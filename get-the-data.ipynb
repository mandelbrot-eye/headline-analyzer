# %%
import os
import json
import time
import requests
import datetime
import dateutil
import pandas as pd
from dateutil.relativedelta import relativedelta
import configparser
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
end = datetime.date(1899, 12, 1) #datetime.date.today()
start = datetime.date(1871, 10, 1) #end - relativedelta(years=1)

# %%
months_in_range = [x.split(' ') for x in pd.date_range(start, end, freq='MS').strftime("%Y %-m").tolist()]

# %%
print(months_in_range)
# Out:
# [['1871', '10'], ['1871', '11'], ['1871', '12'], ['1872', '1'], ['1872', '2'], ['1872', '3'], ['1872', '4'], ['1872', '5'], ['1872', '6'], ['1872', '7'], ['1872', '8'], ['1872', '9'], ['1872', '10'], ['1872', '11'], ['1872', '12'], ['1873', '1'], ['1873', '2'], ['1873', '3'], ['1873', '4'], ['1873', '5'], ['1873', '6'], ['1873', '7'], ['1873', '8'], ['1873', '9'], ['1873', '10'], ['1873', '11'], ['1873', '12'], ['1874', '1'], ['1874', '2'], ['1874', '3'], ['1874', '4'], ['1874', '5'], ['1874', '6'], ['1874', '7'], ['1874', '8'], ['1874', '9'], ['1874', '10'], ['1874', '11'], ['1874', '12'], ['1875', '1'], ['1875', '2'], ['1875', '3'], ['1875', '4'], ['1875', '5'], ['1875', '6'], ['1875', '7'], ['1875', '8'], ['1875', '9'], ['1875', '10'], ['1875', '11'], ['1875', '12'], ['1876', '1'], ['1876', '2'], ['1876', '3'], ['1876', '4'], ['1876', '5'], ['1876', '6'], ['1876', '7'], ['1876', '8'], ['1876', '9'], ['1876', '10'], ['1876', '11'], ['1876', '12'], ['1877', '1'], ['1877', '2'], ['1877', '3'], ['1877', '4'], ['1877', '5'], ['1877', '6'], ['1877', '7'], ['1877', '8'], ['1877', '9'], ['1877', '10'], ['1877', '11'], ['1877', '12'], ['1878', '1'], ['1878', '2'], ['1878', '3'], ['1878', '4'], ['1878', '5'], ['1878', '6'], ['1878', '7'], ['1878', '8'], ['1878', '9'], ['1878', '10'], ['1878', '11'], ['1878', '12'], ['1879', '1'], ['1879', '2'], ['1879', '3'], ['1879', '4'], ['1879', '5'], ['1879', '6'], ['1879', '7'], ['1879', '8'], ['1879', '9'], ['1879', '10'], ['1879', '11'], ['1879', '12'], ['1880', '1'], ['1880', '2'], ['1880', '3'], ['1880', '4'], ['1880', '5'], ['1880', '6'], ['1880', '7'], ['1880', '8'], ['1880', '9'], ['1880', '10'], ['1880', '11'], ['1880', '12'], ['1881', '1'], ['1881', '2'], ['1881', '3'], ['1881', '4'], ['1881', '5'], ['1881', '6'], ['1881', '7'], ['1881', '8'], ['1881', '9'], ['1881', '10'], ['1881', '11'], ['1881', '12'], ['1882', '1'], ['1882', '2'], ['1882', '3'], ['1882', '4'], ['1882', '5'], ['1882', '6'], ['1882', '7'], ['1882', '8'], ['1882', '9'], ['1882', '10'], ['1882', '11'], ['1882', '12'], ['1883', '1'], ['1883', '2'], ['1883', '3'], ['1883', '4'], ['1883', '5'], ['1883', '6'], ['1883', '7'], ['1883', '8'], ['1883', '9'], ['1883', '10'], ['1883', '11'], ['1883', '12'], ['1884', '1'], ['1884', '2'], ['1884', '3'], ['1884', '4'], ['1884', '5'], ['1884', '6'], ['1884', '7'], ['1884', '8'], ['1884', '9'], ['1884', '10'], ['1884', '11'], ['1884', '12'], ['1885', '1'], ['1885', '2'], ['1885', '3'], ['1885', '4'], ['1885', '5'], ['1885', '6'], ['1885', '7'], ['1885', '8'], ['1885', '9'], ['1885', '10'], ['1885', '11'], ['1885', '12'], ['1886', '1'], ['1886', '2'], ['1886', '3'], ['1886', '4'], ['1886', '5'], ['1886', '6'], ['1886', '7'], ['1886', '8'], ['1886', '9'], ['1886', '10'], ['1886', '11'], ['1886', '12'], ['1887', '1'], ['1887', '2'], ['1887', '3'], ['1887', '4'], ['1887', '5'], ['1887', '6'], ['1887', '7'], ['1887', '8'], ['1887', '9'], ['1887', '10'], ['1887', '11'], ['1887', '12'], ['1888', '1'], ['1888', '2'], ['1888', '3'], ['1888', '4'], ['1888', '5'], ['1888', '6'], ['1888', '7'], ['1888', '8'], ['1888', '9'], ['1888', '10'], ['1888', '11'], ['1888', '12'], ['1889', '1'], ['1889', '2'], ['1889', '3'], ['1889', '4'], ['1889', '5'], ['1889', '6'], ['1889', '7'], ['1889', '8'], ['1889', '9'], ['1889', '10'], ['1889', '11'], ['1889', '12'], ['1890', '1'], ['1890', '2'], ['1890', '3'], ['1890', '4'], ['1890', '5'], ['1890', '6'], ['1890', '7'], ['1890', '8'], ['1890', '9'], ['1890', '10'], ['1890', '11'], ['1890', '12'], ['1891', '1'], ['1891', '2'], ['1891', '3'], ['1891', '4'], ['1891', '5'], ['1891', '6'], ['1891', '7'], ['1891', '8'], ['1891', '9'], ['1891', '10'], ['1891', '11'], ['1891', '12'], ['1892', '1'], ['1892', '2'], ['1892', '3'], ['1892', '4'], ['1892', '5'], ['1892', '6'], ['1892', '7'], ['1892', '8'], ['1892', '9'], ['1892', '10'], ['1892', '11'], ['1892', '12'], ['1893', '1'], ['1893', '2'], ['1893', '3'], ['1893', '4'], ['1893', '5'], ['1893', '6'], ['1893', '7'], ['1 ...

# %%
def send_request(date):
    '''Sends a request to the NYT Archive API for given date.'''
    base_url = 'https://api.nytimes.com/svc/archive/v1/'
    url = base_url + '/' + date[0] + '/' + date[1] + '.json?api-key=' + 'HejIZPA3o6sinrCI3LBrvGXYUKVviaY8'
    try:
        response = requests.get(url, verify=False).json()
    except Exception:
        return None
    time.sleep(6)
    return response


def is_valid(article, date):
    '''An article is only worth checking if it is in range, and has a headline.'''
    is_in_range = date > start and date < end
    has_headline = type(article['headline']) == dict and 'main' in article['headline'].keys()
    return is_in_range and has_headline


def parse_response(response):
    '''Parses and returns response as pandas data frame.'''
    data = {'headline': [], 
        'abstract': [],
        'snippet': [], 
        'date': [], 
        'doc_type': [],
        'material_type': [],
        'news_desk': [],
        'section_name': [],
        'subsection_name': [],
        'word_count': [],
        'keywords': [],
        'web_url': []}
    
    articles = response['response']['docs'] 
    for article in articles: # For each article, make sure it falls within our date range
        date = dateutil.parser.parse(article['pub_date']).date()
        if is_valid(article, date):
            data['date'].append(date)
            data['headline'].append(article['headline']['main']) 
            if 'section_name' in article:
                data['section_name'].append(article['section_name'])
            else:
                data['section_name'].append(None)
            if 'subsection_name' in article:
                data['subsection_name'].append(article['subsection_name'])
            else:
                data['subsection_name'].append(None)
            data['doc_type'].append(article['document_type'])
            if 'abstract' in article:
                data['abstract'].append(article['abstract'])
            else:
                data['abstract'].append(None)
            if 'snippet' in article:
                data['snippet'].append(article['snippet'])
            else:
                data['snippet'].append(None)
            if 'type_of_material' in article: 
                data['material_type'].append(article['type_of_material'])
            else:
                data['material_type'].append(None)
            if 'news_desk' in article:
                data['news_desk'].append(article['news_desk'])
            else:
                data['news_desk'].append(None)
            if 'word_count' in article:
                data['word_count'].append(article['word_count'])
            else:
                data['word_count'].append(None)
            if 'web_url' in article:
                data['web_url'].append(article['web_url'])
            else:
                data['web_url'].append(None)
            keywords = [keyword['value'] for keyword in article['keywords'] if keyword['name'] == 'subject']
            data['keywords'].append(keywords)
    return pd.DataFrame(data) 


def get_data(dates):
    '''Sends and parses request/response to/from NYT Archive API for given dates.'''
    total = 0
    print('Date range: ' + str(dates[0]) + ' to ' + str(dates[-1]))
    if not os.path.exists('headlines'):
        os.mkdir('headlines')
    for date in dates:
        response = send_request(date)
        df = parse_response(response)
        total += len(df)
        df.to_csv('headlines/' + date[0] + '-' + date[1] + '.csv', index=False)
        print('Saving headlines/' + date[0] + '-' + date[1] + '.csv...')
    print('Number of articles collected: ' + str(total))

# %%
get_data(months_in_range)
# Out:
# Date range: ['1871', '10'] to ['1899', '12']
# Saving headlines/1871-10.csv...
# Saving headlines/1871-11.csv...
# Saving headlines/1871-12.csv...
# Saving headlines/1872-1.csv...
# Saving headlines/1872-2.csv...
# Saving headlines/1872-3.csv...
# Saving headlines/1872-4.csv...
# Saving headlines/1872-5.csv...
# Saving headlines/1872-6.csv...
# Saving headlines/1872-7.csv...
# Saving headlines/1872-8.csv...
# Saving headlines/1872-9.csv...
# Saving headlines/1872-10.csv...
# Saving headlines/1872-11.csv...
# Saving headlines/1872-12.csv...
# Saving headlines/1873-1.csv...
# Saving headlines/1873-2.csv...
# Saving headlines/1873-3.csv...
# Saving headlines/1873-4.csv...
# Saving headlines/1873-5.csv...
# Saving headlines/1873-6.csv...
# Saving headlines/1873-7.csv...
# Saving headlines/1873-8.csv...
# Saving headlines/1873-9.csv...
# Saving headlines/1873-10.csv...
# Saving headlines/1873-11.csv...
# Saving headlines/1873-12.csv...
# Saving headlines/1874-1.csv...
# Saving headlines/1874-2.csv...
# Saving headlines/1874-3.csv...
# Saving headlines/1874-4.csv...
# Saving headlines/1874-5.csv...
# Saving headlines/1874-6.csv...
# Saving headlines/1874-7.csv...
# Saving headlines/1874-8.csv...
# Saving headlines/1874-9.csv...
# Saving headlines/1874-10.csv...
# Saving headlines/1874-11.csv...
# Saving headlines/1874-12.csv...
# Saving headlines/1875-1.csv...
# Saving headlines/1875-2.csv...
# Saving headlines/1875-3.csv...
# Saving headlines/1875-4.csv...
# Saving headlines/1875-5.csv...
# Saving headlines/1875-6.csv...
# Saving headlines/1875-7.csv...
# Saving headlines/1875-8.csv...
# Saving headlines/1875-9.csv...
# Saving headlines/1875-10.csv...
# Saving headlines/1875-11.csv...
# Saving headlines/1875-12.csv...
# Saving headlines/1876-1.csv...
# Saving headlines/1876-2.csv...
# Saving headlines/1876-3.csv...
# Saving headlines/1876-4.csv...
# Saving headlines/1876-5.csv...
# Saving headlines/1876-6.csv...
# Saving headlines/1876-7.csv...
# Saving headlines/1876-8.csv...
# Saving headlines/1876-9.csv...
# Saving headlines/1876-10.csv...
# Saving headlines/1876-11.csv...
# Saving headlines/1876-12.csv...
# Saving headlines/1877-1.csv...
# Saving headlines/1877-2.csv...
# Saving headlines/1877-3.csv...
# Saving headlines/1877-4.csv...
# Saving headlines/1877-5.csv...
# Saving headlines/1877-6.csv...
# Saving headlines/1877-7.csv...
# Saving headlines/1877-8.csv...
# Saving headlines/1877-9.csv...
# Saving headlines/1877-10.csv...
# Saving headlines/1877-11.csv...
# Saving headlines/1877-12.csv...
# Saving headlines/1878-1.csv...
# Saving headlines/1878-2.csv...
# Saving headlines/1878-3.csv...
# Saving headlines/1878-4.csv...
# Saving headlines/1878-5.csv...
# Saving headlines/1878-6.csv...
# Saving headlines/1878-7.csv...
# Saving headlines/1878-8.csv...
# Saving headlines/1878-9.csv...
# Saving headlines/1878-10.csv...
# Saving headlines/1878-11.csv...
# Saving headlines/1878-12.csv...
# Saving headlines/1879-1.csv...
# Saving headlines/1879-2.csv...
# Saving headlines/1879-3.csv...
# Saving headlines/1879-4.csv...
# Saving headlines/1879-5.csv...
# Saving headlines/1879-6.csv...
# Saving headlines/1879-7.csv...
# Saving headlines/1879-8.csv...
# Saving headlines/1879-9.csv...
# Saving headlines/1879-10.csv...
# Saving headlines/1879-11.csv...
# Saving headlines/1879-12.csv...
# Saving headlines/1880-1.csv...
# Saving headlines/1880-2.csv...
# Saving headlines/1880-3.csv...
# Saving headlines/1880-4.csv...
# Saving headlines/1880-5.csv...
# Saving headlines/1880-6.csv...
# Saving headlines/1880-7.csv...
# Saving headlines/1880-8.csv...
# Saving headlines/1880-9.csv...
# Saving headlines/1880-10.csv...
# Saving headlines/1880-11.csv...
# Saving headlines/1880-12.csv...
# Saving headlines/1881-1.csv...
# Saving headlines/1881-2.csv...
# Saving headlines/1881-3.csv...
# Saving headlines/1881-4.csv...
# Saving headlines/1881-5.csv...
# Saving headlines/1881-6.csv...
# Saving headlines/1881-7.csv...
# Saving headlines/1881-8.csv...
# Saving headlines/1881-9.csv...
# Saving headlines/1881-10.csv...
# Saving headlines/1881-11.csv...
# Saving headlines/1881-12.csv...
# Saving headlines/1882-1.csv...
# Saving headlines/1882-2.csv...
# Saving headlines/1882-3.csv...
# Saving headlines/1882-4.csv...
# Saving headlines/1882-5.csv...
# Saving headlines/1882-6.csv...
# Saving headlines/1882-7.csv...
# Saving headlines/1882-8.csv...
# Saving headlines/1882-9.csv...
# Saving headlines/1882-10.csv...
# Saving headlines/1882-11.csv...
# Saving headlines/1882-12.csv...
# Saving headlines/1883-1.csv...
# Saving headlines/1883-2.csv...
# Saving headlines/1883-3.csv...
# Saving headlines/1883-4.csv...
# Saving headlines/1883-5.csv...
# Saving headlines/1883-6.csv...
# Saving headlines/1883-7.csv...
# Saving headlines/1883-8.csv...
# Saving headlines/1883-9.csv...
# Saving headlines/1883-10.csv...
# Saving headlines/1883-11.csv...
# Saving headlines/1883-12.csv...
# Saving headlines/1884-1.csv...
# Saving headlines/1884-2.csv...
# Saving headlines/1884-3.csv...
# Saving headlines/1884-4.csv...
# Saving headlines/1884-5.csv...
# Saving headlines/1884-6.csv...
# Saving headlines/1884-7.csv...
# Saving headlines/1884-8.csv...
# Saving headlines/1884-9.csv...
# Saving headlines/1884-10.csv...
# Saving headlines/1884-11.csv...
# Saving headlines/1884-12.csv...
# Saving headlines/1885-1.csv...
# Saving headlines/1885-2.csv...
# Saving headlines/1885-3.csv...
# Saving headlines/1885-4.csv...
# Saving headlines/1885-5.csv...
# Saving headlines/1885-6.csv...
# Saving headlines/1885-7.csv...
# Saving headlines/1885-8.csv...
# Saving headlines/1885-9.csv...
# Saving headlines/1885-10.csv...
# Saving headlines/1885-11.csv...
# Saving headlines/1885-12.csv...
# Saving headlines/1886-1.csv...
# Saving headlines/1886-2.csv...
# Saving headlines/1886-3.csv...
# Saving headlines/1886-4.csv...
# Saving headlines/1886-5.csv...
# Saving headlines/1886-6.csv...
# Saving headlines/1886-7.csv...
# Saving headlines/1886-8.csv...
# Saving headlines/1886-9.csv...
# Saving headlines/1886-10.csv...
# Saving headlines/1886-11.csv...
# Saving headlines/1886-12.csv...
# Saving headlines/1887-1.csv...
# Saving headlines/1887-2.csv...
# Saving headlines/1887-3.csv...
# Saving headlines/1887-4.csv...
# Saving headlines/1887-5.csv...
# Saving headlines/1887-6.csv...
# Saving headlines/1887-7.csv...
# Saving headlines/1887-8.csv...
# Saving headlines/1887-9.csv...
# Saving headlines/1887-10.csv...
# Saving headlines/1887-11.csv...
# Saving headlines/1887-12.csv...
# Saving headlines/1888-1.csv...
# Saving headlines/1888-2.csv...
# Saving headlines/1888-3.csv...
# Saving headlines/1888-4.csv...
# Saving headlines/1888-5.csv...
# Saving headlines/1888-6.csv...
# Saving headlines/1888-7.csv...
# Saving headlines/1888-8.csv...
# Saving headlines/1888-9.csv...
# Saving headlines/1888-10.csv...
# Saving headlines/1888-11.csv...
# Saving headlines/1888-12.csv...
# Saving headlines/1889-1.csv...
# Saving headlines/1889-2.csv...
# Saving headlines/1889-3.csv...
# Saving headlines/1889-4.csv...
# Saving headlines/1889-5.csv...
# Saving headlines/1889-6.csv...
# Saving headlines/1889-7.csv...
# Saving headlines/1889-8.csv...
# Saving headlines/1889-9.csv...
# Saving headlines/1889-10.csv...
# Saving headlines/1889-11.csv...
# Saving headlines/1889-12.csv...
# Saving headlines/1890-1.csv...
# Saving headlines/1890-2.csv...
# Saving headlines/1890-3.csv...
# Saving headlines/1890-4.csv...
# Saving headlines/1890-5.csv...
# Saving headlines/1890-6.csv...
# Saving headlines/1890-7.csv...
# Saving headlines/1890-8.csv...
# Saving headlines/1890-9.csv...
# Saving headlines/1890-10.csv...
# Saving headlines/1890-11.csv...
# Saving headlines/1890-12.csv...
# Saving headlines/1891-1.csv...
# Saving headlines/1891-2.csv...
# Saving headlines/1891-3.csv...
# Saving headlines/1891-4.csv...
# Saving headlines/1891-5.csv...
# Saving headlines/1891-6.csv...
# Saving headlines/1891-7.csv...
# Saving headlines/1891-8.csv...
# Saving headlines/1891-9.csv...
# Saving headlines/1891-10.csv...
# Saving headlines/1891-11.csv...
# Saving headlines/1891-12.csv...
# Saving headlines/1892-1.csv...
# Saving headlines/1892-2.csv...
# Saving headlines/1892-3.csv...
# Saving headlines/1892-4.csv...
# Saving headlines/1892-5.csv...
# Saving headlines/1892-6.csv...
# Saving headlines/1892-7.csv...
# Saving headlines/1892-8.csv...
# Saving headlines/1892-9.csv...
# Saving headlines/1892-10.csv...
# Saving headlines/1892-11.csv...
# Saving headlines/1892-12.csv...
# Saving headlines/1893-1.csv...
# Saving headlines/1893-2.csv...
# Saving headlines/1893-3.csv...
# Saving headlines/1893-4.csv...
# Saving headlines/1893-5.csv...
# Saving headlines/1893-6.csv...
# Saving headlines/1893-7.csv...
# Saving headlines/1893-8.csv...
# Saving headlines/1893-9.csv...
# Saving headlines/1893-10.csv...
# Saving headlines/1893-11.csv...
# Saving headlines/1893-12.csv...
# Saving headlines/1894-1.csv...
# Saving headlines/1894-2.csv...
# Saving headlines/1894-3.csv...
# Saving headlines/1894-4.csv...
# Saving headlines/1894-5.csv...
# Saving headlines/1894-6.csv...
# Saving headlines/1894-7.csv...
# Saving headlines/1894-8.csv...
# Saving headlines/1894-9.csv...
# Saving headlines/1894-10.csv...
# Saving headlines/1894-11.csv...
# Saving headlines/1894-12.csv...
# Saving headlines/1895-1.csv...
# Saving headlines/1895-2.csv...
# Saving headlines/1895-3.csv...
# Saving headlines/1895-4.csv...
# Saving headlines/1895-5.csv...
# Saving headlines/1895-6.csv...
# Saving headlines/1895-7.csv...
# Saving headlines/1895-8.csv...
# Saving headlines/1895-9.csv...
# Saving headlines/1895-10.csv...
# Saving headlines/1895-11.csv...
# Saving headlines/1895-12.csv...
# Saving headlines/1896-1.csv...
# Saving headlines/1896-2.csv...
# Saving headlines/1896-3.csv...
# Saving headlines/1896-4.csv...
# Saving headlines/1896-5.csv...
# Saving headlines/1896-6.csv...
# Saving headlines/1896-7.csv...
# Saving headlines/1896-8.csv...
# Saving headlines/1896-9.csv...
# Saving headlines/1896-10.csv...
# Saving headlines/1896-11.csv...
# Saving headlines/1896-12.csv...
# Saving headlines/1897-1.csv...
# Saving headlines/1897-2.csv...
# Saving headlines/1897-3.csv...
# Saving headlines/1897-4.csv...
# Saving headlines/1897-5.csv...
# Saving headlines/1897-6.csv...
# Saving headlines/1897-7.csv...
# Saving headlines/1897-8.csv...
# Saving headlines/1897-9.csv...
# Saving headlines/1897-10.csv...
# Saving headlines/1897-11.csv...
# Saving headlines/1897-12.csv...
# Saving headlines/1898-1.csv...
# Saving headlines/1898-2.csv...
# Saving headlines/1898-3.csv...
# Saving headlines/1898-4.csv...
# Saving headlines/1898-5.csv...
# Saving headlines/1898-6.csv...
# Saving headlines/1898-7.csv...
# Saving headlines/1898-8.csv...
# Saving headlines/1898-9.csv...
# Saving headlines/1898-10.csv...
# Saving headlines/1898-11.csv...
# Saving headlines/1898-12.csv...
# Saving headlines/1899-1.csv...
# Saving headlines/1899-2.csv...
# Saving headlines/1899-3.csv...
# Saving headlines/1899-4.csv...
# Saving headlines/1899-5.csv...
# Saving headlines/1899-6.csv...
# Saving headlines/1899-7.csv...
# Saving headlines/1899-8.csv...
# Saving headlines/1899-9.csv...
# Saving headlines/1899-10.csv...
# Saving headlines/1899-11.csv...
# Saving headlines/1899-12.csv...
# Number of articles collected: 1430820

# %%
response

# %%
import requests
your_key = 'HejIZPA3o6sinrCI3LBrvGXYUKVviaY8'
url = 'https://api.nytimes.com/svc/archive/v1/2022/11.json?&api-key=' + your_key
r = requests.get(url)
json_data = r.json()

# %%
json_data
